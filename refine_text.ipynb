# %%
# !pip install nltk

# %%
import os
import glob
import numpy as np
import pandas as pd

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
lemmatizer = WordNetLemmatizer()

# %%
a_file = open("word_file/nn_car.txt", "r")
lines = a_file.readlines()
a_file.close()

# %%
new_file = open("word_file/nn_car.txt", "w")
for line in lines:
    contains_digit = any(map(str.isdigit, line))
    if not contains_digit:
        new_file.write(line)
new_file.close()

# %%
a_file = open("OneLook.txt", "r")
lines = a_file.readlines()
a_file.close()

new_file = open("OneLook.txt", "w")
for line in lines:
    contains_digit = any(map(str.isdigit, line))
    if contains_digit:
        _, r = line.split('. ')
        new_file.write(r)
new_file.close()

# %%
txt_files = glob.glob("word_file/*.txt")
txt_files
# Out:
# ['word_file/collates_nn_30left.txt',
#  'word_file/car_n.txt',
#  'word_file/relatedwords.txt',
#  'word_file/collates_nn_03right.txt',
#  'word_file/collates04right.txt',
#  'word_file/collates10left.txt',
#  'word_file/collates30left.txt',
#  'word_file/collates02right.txt',
#  'word_file/collates03right.txt',
#  'word_file/collates_nn_01right.txt',
#  'word_file/collates20left.txt',
#  'word_file/collates01right.txt',
#  'word_file/collates_nn_02right.txt',
#  'word_file/OneLook.txt',
#  'word_file/collates_nn_04right.txt',
#  'word_file/nn_car.txt',
#  'word_file/collates40left.txt',
#  'word_file/collates_nn_20left.txt',
#  'word_file/n_car.txt',
#  'word_file/collates_nn_40left.txt',
#  'word_file/car_nn.txt',
#  'word_file/collates_nn_10left.txt']

# %%
for file in txt_files:
    a_file = open(file, "r")
    lines = a_file.readlines()
    a_file.close()
    
    new_file = open(file, "w")
    for line in lines:
        if not line.isspace():
            line.strip()
            new_file.write(line)
    new_file.close()

# %%
for file in txt_files:
    a_file = open(file, "r")
    lines = a_file.readlines()
    a_file.close()
    
    new_file = open(file, "w")
    for line in lines:
        new_file.write(line.strip() + '\n')
    new_file.close()

# %%
txt_files = glob.glob("word_file/car_*.txt")
txt_files
# Out:
# ['word_file/car_n.txt', 'word_file/car_nn.txt']

# %%
for file in txt_files:
    a_file = open(file, "r")
    lines = a_file.readlines()
    a_file.close()
    
    new_file = open(file, "w")
    for line in lines:
        _, r = line.split(' ')
        new_file.write(r)
    new_file.close()

# %%
txt_files = glob.glob("word_file/n*.txt")
txt_files
# Out:
# ['word_file/nn_car.txt', 'word_file/n_car.txt']

# %%
for file in txt_files:
    a_file = open(file, "r")
    lines = a_file.readlines()
    a_file.close()
    
    new_file = open(file, "w")
    for line in lines:
        l, _ = line.split(' ')
        new_file.write(l + '\n')
    new_file.close()

# %%
txt_files = glob.glob("word_file/*.txt")
txt_files
# Out:
# ['word_file/collates_nn_30left.txt',
#  'word_file/car_n.txt',
#  'word_file/relatedwords.txt',
#  'word_file/collates_nn_03right.txt',
#  'word_file/collates04right.txt',
#  'word_file/collates10left.txt',
#  'word_file/collates30left.txt',
#  'word_file/collates02right.txt',
#  'word_file/collates03right.txt',
#  'word_file/collates_nn_01right.txt',
#  'word_file/collates20left.txt',
#  'word_file/collates01right.txt',
#  'word_file/collates_nn_02right.txt',
#  'word_file/OneLook.txt',
#  'word_file/collates_nn_04right.txt',
#  'word_file/nn_car.txt',
#  'word_file/collates40left.txt',
#  'word_file/collates_nn_20left.txt',
#  'word_file/n_car.txt',
#  'word_file/collates_nn_40left.txt',
#  'word_file/car_nn.txt',
#  'word_file/collates_nn_10left.txt']

# %%
all_words = []
for file in txt_files:
    a_file = open(file, "r")
    lines = a_file.readlines()
    lines = [el.strip().lower() for el in lines]
    all_words.extend(lines)
    a_file.close()
all_words = set(all_words)

# %%
all_words
# Out:
# {'line',
#  'flipped',
#  'funeral',
#  'gray',
#  'getting',
#  'back',
#  'strangers',
#  'received',
#  'malibu',
#  'side',
#  'beaten',
#  'model',
#  'police',
#  'serviceable',
#  'coupe',
#  't',
#  'wrought',
#  'first',
#  'pressed',
#  'is',
#  'of',
#  'approached',
#  'designed',
#  'their',
#  'loaders',
#  'vehicle',
#  'it',
#  'only',
#  'those',
#  'night',
#  'developed',
#  'bombs',
#  'repairs',
#  'impact',
#  'vice',
#  'subway',
#  'eighty',
#  'eft',
#  'drinking',
#  'rentals',
#  'compartment',
#  'consider',
#  'starter',
#  'pace',
#  'fleet',
#  'driver',
#  'autos',
#  'parts',
#  'plastic',
#  'its',
#  'thick',
#  'talking',
#  'sparrows',
#  'to',
#  'refrigerated',
#  'flooded',
#  'fixes',
#  'warmth',
#  'minicar',
#  'car window',
#  'she',
#  'omnibus',
#  'lounge',
#  'write',
#  'safekeeping',
#  'victory',
#  'freight',
#  'floating',
#  'furnish',
#  'enable',
#  "man's",
#  'midst',
#  'oldsmobile',
#  'hung',
#  'also',
#  'offices',
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/barzamini/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/barzamini/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
filtered_words = [word for word in all_words if word not in stopwords.words('english') and ' ' not in word]
filtered_words
# Out:
# ['line',
#  'flipped',
#  'funeral',
#  'gray',
#  'getting',
#  'back',
#  'strangers',
#  'received',
#  'malibu',
#  'side',
#  'beaten',
#  'model',
#  'police',
#  'serviceable',
#  'coupe',
#  'wrought',
#  'first',
#  'pressed',
#  'approached',
#  'designed',
#  'loaders',
#  'vehicle',
#  'night',
#  'developed',
#  'bombs',
#  'repairs',
#  'impact',
#  'vice',
#  'subway',
#  'eighty',
#  'eft',
#  'drinking',
#  'rentals',
#  'compartment',
#  'consider',
#  'starter',
#  'pace',
#  'fleet',
#  'driver',
#  'autos',
#  'parts',
#  'plastic',
#  'thick',
#  'talking',
#  'sparrows',
#  'refrigerated',
#  'flooded',
#  'fixes',
#  'warmth',
#  'minicar',
#  'omnibus',
#  'lounge',
#  'write',
#  'safekeeping',
#  'victory',
#  'freight',
#  'floating',
#  'furnish',
#  'enable',
#  "man's",
#  'midst',
#  'oldsmobile',
#  'hung',
#  'also',
#  'offices',
#  'observation',
#  'cadillac',
#  'celui',
#  'fares',
#  'examination',
#  'wants',
#  'hearse',
#  'proud',
# ...

# %%
len(filtered_words)
# Out:
# 1053

# %%
not_stemed_filtered_words = [el.replace(" ", "_") for el in filtered_words if ' ' not in el]

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

# %%
stemed_filtered_words = set([porter.stem(el).replace(" ", "_") for el in filtered_words])
stemed_filtered_words = [el.replace(" ", "_") for el in stemed_filtered_words]
stemed_filtered_words
# Out:
# ['line',
#  'toy',
#  'malibu',
#  'gray',
#  'back',
#  'cri',
#  'consign',
#  'beaten',
#  'model',
#  'mount',
#  'proport',
#  'porter',
#  'side',
#  'first',
#  'wrought',
#  'moder',
#  'vice',
#  'overcrowd',
#  'hug',
#  'night',
#  'groceri',
#  'impact',
#  'subway',
#  'eft',
#  'happen',
#  'content',
#  'pass',
#  'burn',
#  'starter',
#  'flag',
#  'pace',
#  'fleet',
#  'downstair',
#  'driver',
#  'motorcad',
#  'wrap',
#  'lip',
#  'increas',
#  'smash',
#  'thick',
#  'plastic',
#  'angl',
#  'refriger',
#  'book',
#  'handsom',
#  'machineri',
#  'warmth',
#  'minicar',
#  'construct',
#  'write',
#  'leas',
#  'jack',
#  'mileag',
#  'freight',
#  'furnish',
#  'bounc',
#  'midst',
#  'rais',
#  'economi',
#  'hung',
#  'also',
#  'cadillac',
#  'celui',
#  'spin',
#  'troubl',
#  'proud',
#  'pellucid',
#  'usual',
#  'noth',
#  'beep',
#  'tour',
#  'hungri',
#  'distanc',
#  'worri',
#  'depart',
#  'loung',
#  'matchbox',
#  'exhaust',
#  'twenti',
# ...

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
len(stemed_filtered_words)
# Out:
# 948

# %%
import gensim.downloader
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
glove_vectors = gensim.downloader.load('glove-wiki-gigaword-300')

# %%
! ls ~/gensim-data
# Out:
# fasttext-wiki-news-subwords-300  information.json
# glove-twitter-200		 __testing_multipart-matrix-synopsis
# glove-twitter-25		 word2vec-google-news-300
# glove-wiki-gigaword-300

# %%
data = []
for w in not_stemed_filtered_words:
    if w in glove_vectors.index_to_key:
        sim_val = glove_vectors.similarity("car", w)
        print(f'similarity score for {w} is: {sim_val}')
    else:
        print(f'{w} not presented in the gensim model')
        sim_val = np.nan
    data.append([w, sim_val])
    print('\n __________________________________________ \n')
# Out:
# similarity score for line is: 0.26520583033561707
#
#  __________________________________________
#
# similarity score for flipped is: 0.31860512495040894
#
#  __________________________________________
#
# similarity score for funeral is: 0.2656096816062927
#
#  __________________________________________
#
# similarity score for gray is: 0.13969425857067108
#
#  __________________________________________
#
# similarity score for getting is: 0.3189148008823395
#
#  __________________________________________
#
# similarity score for back is: 0.35283854603767395
#
#  __________________________________________
#
# similarity score for strangers is: 0.171281099319458
#
#  __________________________________________
#
# similarity score for received is: 0.19844362139701843
#
#  __________________________________________
#
# similarity score for malibu is: 0.23311831057071686
#
#  __________________________________________
#
# similarity score for side is: 0.2901405990123749
#
# ...

# %%
not_stemed_words_df = pd.DataFrame(data, columns = ['word', 'similarity'])
pd.set_option('display.max_rows', None)
not_stemed_words_df = not_stemed_words_df.sort_values('similarity', ascending=False, ignore_index=True)
not_stemed_words_df = not_stemed_words_df.iloc[1: , :]
not_stemed_words_df
# Out:
#                  word  similarity
# 1             vehicle    0.765537
# 2               truck    0.735062
# 3              driver    0.711478
# 4             driving    0.644223
# 5            vehicles    0.632800
# 6          motorcycle    0.602251
# 7          automobile    0.595573
# 8             drivers    0.577836
# 9                 suv    0.573907
# 10                bus    0.565325
# 11           mercedes    0.558628
# 12               auto    0.557272
# 13              drove    0.551145
# 14               taxi    0.542710
# 15               jeep    0.536467
# 16             garage    0.535601
# 17         dealership    0.522157
# 18              drive    0.516160
# 19              motor    0.512136
# 20          passenger    0.510087
# 21              wheel    0.508198
# 22               bomb    0.502516
# 23            minivan    0.501412
# 24            bicycle    0.497951
# 25              sedan    0.496989
# 26           accident    0.493806
# ...

# %%
not_stemed_words_df.to_csv('not_stemmed_word_based_wiki_score.csv', index=False)

# %%
data = []
for w in stemed_filtered_words:
    if w in glove_vectors.index_to_key:
        sim_val = glove_vectors.similarity("car", w)
        print(f'similarity score for {w} is: {sim_val}')
    else:
        print(f'{w} not presented in the gensim model')
        sim_val = np.nan
    data.append([w, sim_val])
    print('\n __________________________________________ \n')
# Out:
# garag not presented in the gensim model
#
#  __________________________________________
#
# similarity score for toyota is: 0.4840026795864105
#
#  __________________________________________
#
# similarity score for mort is: -0.07774154096841812
#
#  __________________________________________
#
# downstair not presented in the gensim model
#
#  __________________________________________
#
# lifetim not presented in the gensim model
#
#  __________________________________________
#
# similarity score for one is: 0.4110254943370819
#
#  __________________________________________
#
# similarity score for lege is: -0.27822551131248474
#
#  __________________________________________
#
# similarity score for room is: 0.3002089262008667
#
#  __________________________________________
#
# similarity score for denni is: -0.1965385377407074
#
#  __________________________________________
#
# similarity score for whose is: 0.2761419415473938
#
#  __________________________________________
#
# ...

# %%
stemed_words_df = pd.DataFrame(data, columns = ['word', 'similarity'])
pd.set_option('display.max_rows', None)
stemed_words_df = stemed_words_df.sort_values('similarity', ascending=False, ignore_index=True)
stemed_words_df = stemed_words_df.iloc[1: , :]
stemed_words_df
# Out:
#              word  similarity
# 1           truck    0.735062
# 2          driver    0.711478
# 3             suv    0.573907
# 4            auto    0.557272
# 5           drove    0.551145
# 6            taxi    0.542710
# 7            jeep    0.536467
# 8      dealership    0.522157
# 9           drive    0.516160
# 10          motor    0.512136
# 11          wheel    0.508198
# 12           bomb    0.502516
# 13        minivan    0.501412
# 14          sedan    0.496989
# 15           ford    0.487261
# 16         toyota    0.484003
# 17          crash    0.476257
# 18          train    0.467336
# 19            cab    0.459555
# 20           tire    0.452059
# 21           door    0.448675
# 22           cart    0.437872
# 23           shop    0.424542
# 24           ride    0.417633
# 25          wagon    0.414176
# 26         rental    0.413759
# 27            one    0.411025
# 28       cadillac    0.409007
# 29          speed    0.408913
# 30        getaway    0.407191
# ...

# %%
stemed_words_df.to_csv('partial_data_based_wiki_score.csv', index=False)

# %% [markdown]
# # Pedestrian

# %%
txt_files = glob.glob("word_file/pedestrian/*.txt")
txt_files
# Out:
# ['word_file/pedestrian/onelook.txt',
#  'word_file/pedestrian/nn30.txt',
#  'word_file/pedestrian/nn01.txt',
#  'word_file/pedestrian/n30.txt',
#  'word_file/pedestrian/n40.txt',
#  'word_file/pedestrian/n01.txt',
#  'word_file/pedestrian/nn03.txt',
#  'word_file/pedestrian/nn04.txt',
#  'word_file/pedestrian/nn10.txt',
#  'word_file/pedestrian/ped_n.txt',
#  'word_file/pedestrian/relatedword.txt',
#  'word_file/pedestrian/n03.txt',
#  'word_file/pedestrian/ped_nn.txt',
#  'word_file/pedestrian/nn_ped.txt',
#  'word_file/pedestrian/nn20.txt',
#  'word_file/pedestrian/nn02.txt',
#  'word_file/pedestrian/n04.txt',
#  'word_file/pedestrian/n02.txt',
#  'word_file/pedestrian/nn40.txt',
#  'word_file/pedestrian/n_ped.txt',
#  'word_file/pedestrian/n10.txt',
#  'word_file/pedestrian/n20.txt']

# %%
for file in txt_files:
    a_file = open(file, "r")
    lines = a_file.readlines()
    a_file.close()
    
    new_file = open(file, "w")
    for line in lines:
        if not line.isspace():
            line.strip()
            new_file.write(line)
    new_file.close()

# %%
all_words = []
for file in txt_files:
    a_file = open(file, "r")
    lines = a_file.readlines()
    lines = [el.strip().lower() for el in lines]
    all_words.extend(lines)
    a_file.close()
all_words = set(all_words)
all_words
# Out:
# {'access',
#  'accessroad',
#  'accident',
#  'accidents',
#  'account',
#  'activities',
#  'activity',
#  'adult',
#  'adults',
#  'air',
#  'amble',
#  'ambler',
#  'ambulatory',
#  'amenities',
#  'amount',
#  'analyses',
#  'analysis',
#  'approach',
#  'area',
#  'areas',
#  'arterial',
#  'arterialroad',
#  'attention',
#  'auto',
#  'automobile',
#  'bark',
#  'bed',
#  'bedroomcommunity',
#  'behavior',
#  'belishabeacon',
#  'bicycle',
#  'bicyclerack',
#  'bicyclist',
#  'bike',
#  'blindcurve',
#  'block',
#  'boots',
#  'bridge',
#  'bridges',
#  'british english',
#  'building',
#  'buildings',
#  'busdepot',
#  'businessdistrict',
#  'bystander',
#  'canoe',
#  'cantileverbridge',
#  'car',
#  'carriage',
#  'carson',
#  'case',
#  'chance',
#  'chances',
#  'character',
#  'child',
#  'childhood',
#  'childs',
#  'circulation',
#  'city',
#  'citys',
#  'cobblestone',
#  'collision',
#  'collisions',
#  'comparison',
#  'concourse',
#  'congested',
#  'connections',
# ...

# %%
len(all_words)
# Out:
# 415

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/barzamini/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))
filtered_words = [word for word in all_words if word not in stopwords.words('english') and ' ' not in word]
not_stemed_filtered_words = [el.replace(" ", "_") for el in filtered_words if ' ' not in el]
from nltk.stem import PorterStemmer
porter = PorterStemmer()
stemed_filtered_words = set([porter.stem(el).replace(" ", "_") for el in filtered_words])
stemed_filtered_words = [el.replace(" ", "_") for el in stemed_filtered_words]
import gensim.downloader
print(list(gensim.downloader.info()['models'].keys()))
glove_vectors = gensim.downloader.load('glove-wiki-gigaword-300')

data = []

for w in not_stemed_filtered_words:
    if w in glove_vectors.index_to_key:
        sim_val = glove_vectors.similarity("pedestrian", w)
        print(f'similarity score for {w} is: {sim_val}')
    else:
        print(f'{w} not presented in the gensim model')
        sim_val = np.nan
    data.append([w, sim_val])
    print('\n __________________________________________ \n')
    
not_stemed_words_df = pd.DataFrame(data, columns = ['word', 'similarity'])
pd.set_option('display.max_rows', None)
not_stemed_words_df = not_stemed_words_df.sort_values('similarity', ascending=False, ignore_index=True)
not_stemed_words_df = not_stemed_words_df.iloc[1: , :]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
not_stemed_words_df
# Out:
#                      word  similarity
# 1                 walkway    0.611893
# 2               sidewalks    0.547940
# 3               underpass    0.546047
# 4                   lanes    0.545156
# 5                overpass    0.538890
# 6               vehicular    0.533294
# 7                 traffic    0.525851
# 8            thoroughfare    0.511497
# 9              overpasses    0.501396
# 10             footbridge    0.490623
# 11                parking    0.490274
# 12              crosswalk    0.468198
# 13                   mall    0.468180
# 14            underpasses    0.468007
# 15                 bridge    0.467672
# 16               sidewalk    0.456392
# 17              crossings    0.454379
# 18              promenade    0.454080
# 19                 tunnel    0.442178
# 20                  paths    0.438778
# 21                 plazas    0.432108
# 22               shopping    0.425990
# 23                  malls    0.416754
# 24             crosswalks    0.415963
# ...

# %%
not_stemed_words_df.to_csv('ped_not_stemmed_word_based_wiki_score.csv', index=False)

# %%
data = []
for w in stemed_filtered_words:
    if w in glove_vectors.index_to_key:
        sim_val = glove_vectors.similarity("pedestrian", w)
        print(f'similarity score for {w} is: {sim_val}')
    else:
        print(f'{w} not presented in the gensim model')
        sim_val = np.nan
    data.append([w, sim_val])
    print('\n __________________________________________ \n')

stemed_words_df = pd.DataFrame(data, columns = ['word', 'similarity'])
pd.set_option('display.max_rows', None)
stemed_words_df = stemed_words_df.sort_values('similarity', ascending=False, ignore_index=True)
stemed_words_df = stemed_words_df.iloc[1: , :]
# Out:
# similarity score for lot is: 0.13512879610061646
#
#  __________________________________________
#
# similarity score for leg is: 0.13036128878593445
#
#  __________________________________________
#
# similarity score for plaintiff is: -0.03597242012619972
#
#  __________________________________________
#
# similarity score for light is: 0.14574755728244781
#
#  __________________________________________
#
# similarity score for end is: 0.07870310544967651
#
#  __________________________________________
#
# tramper not presented in the gensim model
#
#  __________________________________________
#
# similarity score for creation is: 0.14418485760688782
#
#  __________________________________________
#
# similarity score for plodder is: 0.12352364510297775
#
#  __________________________________________
#
# similarity score for right is: 0.07490865886211395
#
#  __________________________________________
#
# tollcollector not presented in the gensim model
#
# ...

# %%
stemed_words_df
# Out:
#                      word  similarity
# 1                 walkway    0.611893
# 2               underpass    0.546047
# 3                overpass    0.538890
# 4               vehicular    0.533294
# 5                 traffic    0.525851
# 6               crosswalk    0.468198
# 7                    mall    0.468180
# 8                sidewalk    0.456392
# 9                  tunnel    0.442178
# 10                   road    0.414747
# 11                highway    0.413318
# 12               downtown    0.402182
# 13               footpath    0.402060
# 14                  plaza    0.386931
# 15               corridor    0.382237
# 16               pavement    0.375688
# 17                   bike    0.371826
# 18                   lane    0.367261
# 19             roundabout    0.353104
# 20                connect    0.345346
# 21                   walk    0.342743
# 22                 stroll    0.338361
# 23                 street    0.324142
# 24              eastbound    0.317462
# ...

# %%
stemed_words_df.to_csv('ped_partial_data_based_wiki_score.csv', index=False)

# %%
car_not_stemmed_word = pd.read_csv("not_stemmed_word_based_wiki_score.csv")
car_not_stemmed_word
# Out:
#                  word  similarity
# 0             vehicle    0.765537
# 1               truck    0.735062
# 2              driver    0.711478
# 3             driving    0.644223
# 4            vehicles    0.632800
# 5          motorcycle    0.602251
# 6          automobile    0.595573
# 7             drivers    0.577836
# 8                 suv    0.573907
# 9                 bus    0.565325
# 10           mercedes    0.558628
# 11               auto    0.557272
# 12              drove    0.551145
# 13               taxi    0.542710
# 14               jeep    0.536467
# 15             garage    0.535601
# 16         dealership    0.522157
# 17              drive    0.516160
# 18              motor    0.512136
# 19          passenger    0.510087
# 20              wheel    0.508198
# 21               bomb    0.502516
# 22            minivan    0.501412
# 23            bicycle    0.497951
# 24              sedan    0.496989
# 25           accident    0.493806
# ...

# %%
not_stemed_words_df
# Out:
#                      word  similarity
# 1                 walkway    0.611893
# 2               sidewalks    0.547940
# 3               underpass    0.546047
# 4                   lanes    0.545156
# 5                overpass    0.538890
# 6               vehicular    0.533294
# 7                 traffic    0.525851
# 8            thoroughfare    0.511497
# 9              overpasses    0.501396
# 10             footbridge    0.490623
# 11                parking    0.490274
# 12              crosswalk    0.468198
# 13                   mall    0.468180
# 14            underpasses    0.468007
# 15                 bridge    0.467672
# 16               sidewalk    0.456392
# 17              crossings    0.454379
# 18              promenade    0.454080
# 19                 tunnel    0.442178
# 20                  paths    0.438778
# 21                 plazas    0.432108
# 22               shopping    0.425990
# 23                  malls    0.416754
# 24             crosswalks    0.415963
# ...

# %%
car_not_stemmed_word["word"].tolist()
# Out:
# ['vehicle',
#  'truck',
#  'driver',
#  'driving',
#  'vehicles',
#  'motorcycle',
#  'automobile',
#  'drivers',
#  'suv',
#  'bus',
#  'mercedes',
#  'auto',
#  'drove',
#  'taxi',
#  'jeep',
#  'garage',
#  'dealership',
#  'drive',
#  'motor',
#  'passenger',
#  'wheel',
#  'bomb',
#  'minivan',
#  'bicycle',
#  'sedan',
#  'accident',
#  'ford',
#  'engine',
#  'toyota',
#  'crash',
#  'train',
#  'cab',
#  'parking',
#  'tire',
#  'door',
#  'automobiles',
#  'cart',
#  'airplane',
#  'outside',
#  'engines',
#  'crashes',
#  'suicide',
#  'ride',
#  'limousine',
#  'wagon',
#  'rental',
#  'one',
#  'cadillac',
#  'speed',
#  'getaway',
#  'models',
#  'police',
#  'wrecked',
#  'manufacturer',
#  'automaker',
#  'road',
#  'behind',
#  'wheels',
#  'model',
#  'boat',
#  'inside',
#  'automotive',
#  'jaguar',
#  'near',
#  'motors',
#  'convertible',
#  'parts',
#  'owners',
#  'carriage',
#  'sales',
#  'man',
#  'phone',
#  'stolen',
#  'dealerships',
#  'lights',
# ...

# %%
not_stemed_words_df["word"].tolist()
# Out:
# ['walkway',
#  'sidewalks',
#  'underpass',
#  'lanes',
#  'overpass',
#  'vehicular',
#  'traffic',
#  'thoroughfare',
#  'overpasses',
#  'footbridge',
#  'parking',
#  'crosswalk',
#  'mall',
#  'underpasses',
#  'bridge',
#  'sidewalk',
#  'crossings',
#  'promenade',
#  'tunnel',
#  'paths',
#  'plazas',
#  'shopping',
#  'malls',
#  'crosswalks',
#  'concourse',
#  'road',
#  'highway',
#  'bridges',
#  'congested',
#  'walking',
#  'bicycle',
#  'downtown',
#  'footpath',
#  'roads',
#  'entrance',
#  'tunnels',
#  'landscaped',
#  'plaza',
#  'pathways',
#  'corridor',
#  'pavement',
#  'elevated',
#  'bike',
#  'streets',
#  'lane',
#  'cobblestone',
#  'roundabout',
#  'spaces',
#  'walk',
#  'stroll',
#  'accidents',
#  'street',
#  'fatalities',
#  'eastbound',
#  'parks',
#  'collisions',
#  'vehicle',
#  'precinct',
#  'link',
#  'pathway',
#  'bicyclist',
#  'routes',
#  'transit',
#  'buildings',
#  'arterial',
#  'gate',
#  'path',
#  'motorized',
#  'route',
# ...

# %%
set(not_stemed_words_df["word"].tolist()).intersection(set(car_not_stemmed_word["word"].tolist()))
# Out:
# {'access',
#  'accident',
#  'accidents',
#  'analysis',
#  'areas',
#  'auto',
#  'automobile',
#  'bicycle',
#  'bridge',
#  'carriage',
#  'case',
#  'city',
#  'construction',
#  'control',
#  'day',
#  'design',
#  'distance',
#  'dogs',
#  'door',
#  'downtown',
#  'driver',
#  'end',
#  'fact',
#  'highway',
#  'hours',
#  'injury',
#  'interior',
#  'legs',
#  'light',
#  'line',
#  'lines',
#  'lot',
#  'man',
#  'mile',
#  'motor',
#  'night',
#  'number',
#  'pace',
#  'parking',
#  'parks',
#  'part',
#  'passenger',
#  'problem',
#  'prowl',
#  'road',
#  'safety',
#  'shadow',
#  'side',
#  'sight',
#  'sound',
#  'stream',
#  'street',
#  'style',
#  'system',
#  'time',
#  'traffic',
#  'travel',
#  'trip',
#  'trips',
#  'vehicle',
#  'vehicles',
#  'vehicular',
#  'view',
#  'walk',
#  'world'}

# %%
len(set(not_stemed_words_df["word"].tolist()).intersection(set(car_not_stemmed_word["word"].tolist())))
# Out:
# 65

# %% [markdown]
# # section2

# %%
car_not_stemmed_word = pd.read_csv("not_stemmed_word_based_wiki_score.csv")
car_not_stemmed_word
# Out:
#              word  similarity
# 0         vehicle    0.765537
# 1           truck    0.735062
# 2          driver    0.711478
# 3         driving    0.644223
# 4        vehicles    0.632800
# ...           ...         ...
# 1047      there's         NaN
# 1048   governor's         NaN
# 1049     mother's         NaN
# 1050  passenger's         NaN
# 1051         he's         NaN
#
# [1052 rows x 2 columns]

# %%
ped_not_stemmed_word = pd.read_csv("ped_not_stemmed_word_based_wiki_score.csv")
ped_not_stemmed_word
# Out:
#             word  similarity
# 0        walkway    0.611893
# 1      sidewalks    0.547940
# 2      underpass    0.546047
# 3          lanes    0.545156
# 4       overpass    0.538890
# ..           ...         ...
# 407      hobbler         NaN
# 408    pointduty         NaN
# 409    swaggerer         NaN
# 410      gumwood         NaN
# 411  crossstreet         NaN
#
# [412 rows x 2 columns]

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
w = lemmatizer.lemmatize(el[0], get_wordnet_pos(el[0]))

# %%
car_set = []
for el in car_not_stemmed_word["word"].tolist():
    car_set.append(lemmatizer.lemmatize(el, get_wordnet_pos(el)))
car_set = set(car_set)
len(car_set)
# Out:
# 957

# %%
ped_set = []
for el in ped_not_stemmed_word["word"].tolist():
    ped_set.append(lemmatizer.lemmatize(el, get_wordnet_pos(el)))
ped_set = set(ped_set)
len(ped_set)
# Out:
# 358
